# %% [markdown]
# 🏏 IPL Teams Timeline (2008 - 2023)
# 📌 Active Teams 🟢
# 📌 Defunct / Replaced Teams 🔴
# 📌 Temporary Teams 🟡
#
#
#
# IPL 2008 - Inaugural Season (8 Teams)
# 🟢 Chennai Super Kings (CSK)
# 🟢 Mumbai Indians (MI)
# 🟢 Royal Challengers Bangalore (RCB)
# 🟢 Rajasthan Royals (RR) ✅ Won the first IPL (2008)
# 🟢 Kolkata Knight Riders (KKR)
# 🟢 Delhi Daredevils (DD) (Renamed to Delhi Capitals in 2019)
# 🟢 Kings XI Punjab (KXIP) (Renamed to Punjab Kings in 2021)
# 🔴 Deccan Chargers (DC) (2008-2012, replaced by Sunrisers Hyderabad in 2013)
#
#
#
# IPL 2011 - Expansion (10 Teams)
# 🔹 New Teams Added:
# 9. 🔴 Pune Warriors India (PWI) (2011-2013)
# 10. 🔴 Kochi Tuskers Kerala (KTK) (2011, played only 1 season and was terminated in 2012)
#
#
#
# IPL 2012-2013 (9 Teams)
# Kochi Tuskers Kerala (KTK) exited after 2011
# 🟢 Sunrisers Hyderabad (SRH) (2013-Present, replaced Deccan Chargers)
#
#
#
# IPL 2014-2015 (8 Teams)
# Pune Warriors India (PWI) exited in 2013
#
#
#
# IPL 2016-2017 (8 Teams, CSK & RR Suspended)
# 🔹 New Temporary Teams (Replacing CSK & RR):
# 11. 🟡 Rising Pune Supergiant (RPS) (2016-2017, played 2 seasons)
# 12. 🟡 Gujarat Lions (GL) (2016-2017, played 2 seasons)
#
#
#
# IPL 2018-2021 (8 Teams, CSK & RR Returned)
# 🟢 CSK & RR returned in 2018
# 🟡 RPS & GL exited after 2017
# IPL continued with 8 teams
# IPL 2022-Present (10 Teams, Expansion Again)
# 🔹 New Permanent Teams Added:
# 13. 🟢 Gujarat Titans (GT) (2022-Present, won IPL 2022 in their debut season!)
# 14. 🟢 Lucknow Super Giants (LSG) (2022-Present)
#
# IPL expanded back to 10 teams after 2021.
# 🟢 Active (2023)	CSK, MI, RCB, RR, KKR, DC, PBKS, SRH, GT, LSG
# 🔴 Defunct	Deccan Chargers, Kochi Tuskers Kerala, Pune Warriors India
# 🟡 Temporary	Gujarat Lions, Rising Pune Supergiant

# %%
import pandas as pd 
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"D:\MACHINE LARNING PROJECTS\IPL Win Predictor\dataset\IPL_ball_by_ball_updated.csv")
df
# Out:
#         match_id  season  start_date                             venue  \
# 0         335982    2008  2008-04-18             M Chinnaswamy Stadium
# 1         335982    2008  2008-04-18             M Chinnaswamy Stadium
# 2         335982    2008  2008-04-18             M Chinnaswamy Stadium
# 3         335982    2008  2008-04-18             M Chinnaswamy Stadium
# 4         335982    2008  2008-04-18             M Chinnaswamy Stadium
# ...          ...     ...         ...                               ...
# 243810   1370353    2023  2023-05-29  Narendra Modi Stadium, Ahmedabad
# 243811   1370353    2023  2023-05-29  Narendra Modi Stadium, Ahmedabad
# 243812   1370353    2023  2023-05-29  Narendra Modi Stadium, Ahmedabad
# 243813   1370353    2023  2023-05-29  Narendra Modi Stadium, Ahmedabad
# 243814   1370353    2023  2023-05-29  Narendra Modi Stadium, Ahmedabad
#
#         innings  ball           batting_team                 bowling_team  \
# ...

# %%
df1=pd.read_csv(r"D:\MACHINE LARNING PROJECTS\IPL Win Predictor\dataset\matches_updated_mens_ipl.csv")
df1
# Out:
#                                            venue         umpire2  winner_runs  \
# 0                          M Chinnaswamy Stadium     RE Koertzen        140.0
# 1     Punjab Cricket Association Stadium, Mohali      SL Shastri         33.0
# 2                               Feroz Shah Kotla  GA Pratapkumar          NaN
# 3                               Wankhede Stadium       DJ Harper          NaN
# 4                                   Eden Gardens     K Hariharan          NaN
# ...                                          ...             ...          ...
# 1019            M Chinnaswamy Stadium, Bengaluru       VK Sharma          NaN
# 1020    MA Chidambaram Stadium, Chepauk, Chennai     CB Gaffaney         15.0
# 1021    MA Chidambaram Stadium, Chepauk, Chennai       VK Sharma         81.0
# 1022            Narendra Modi Stadium, Ahmedabad       RJ Tucker         62.0
# 1023            Narendra Modi Stadium, Ahmedabad       RJ Tucker          NaN
#
# ...

# %%
df1.columns
# Out:
# Index(['venue', 'umpire2', 'winner_runs', 'date', 'method', 'reserve_umpire',
#        'winner', 'city', 'balls_per_over', 'outcome', 'match_number',
#        'match_referee', 'team1', 'eliminator', 'date1', 'gender', 'team2',
#        'winner_wickets', 'toss_winner', 'toss_decision', 'date2', 'tv_umpire',
#        'season', 'umpire1', 'event', 'neutralvenue', 'player_of_match',
#        'matchId'],
#       dtype='object')

# %%
for col in df1.columns:
    print(f"{col}:{df1[col].nunique()}")
# Out:
# venue:56
# umpire2:62
# winner_runs:97
# date:762
# method:1
# reserve_umpire:71
# winner:18
# city:35
# balls_per_over:1
# outcome:2
# match_number:72
# match_referee:30
# team1:18
# eliminator:7
# date1:2
# gender:1
# team2:18
# winner_wickets:10
# toss_winner:18
# toss_decision:2
# date2:2
# tv_umpire:69
# season:16
# umpire1:60
# event:1
# neutralvenue:1
# player_of_match:280
# matchId:1024

# %%
df1.drop(columns=['event','method','balls_per_over','date2','neutralvenue','date1','gender','umpire1','match_referee','reserve_umpire','umpire2'],inplace=True)

# %%
df1
# Out:
#                                            venue  winner_runs        date  \
# 0                          M Chinnaswamy Stadium        140.0  2008-04-18
# 1     Punjab Cricket Association Stadium, Mohali         33.0  2008-04-19
# 2                               Feroz Shah Kotla          NaN  2008-04-19
# 3                               Wankhede Stadium          NaN  2008-04-20
# 4                                   Eden Gardens          NaN  2008-04-20
# ...                                          ...          ...         ...
# 1019            M Chinnaswamy Stadium, Bengaluru          NaN  2023-05-21
# 1020    MA Chidambaram Stadium, Chepauk, Chennai         15.0  2023-05-23
# 1021    MA Chidambaram Stadium, Chepauk, Chennai         81.0  2023-05-24
# 1022            Narendra Modi Stadium, Ahmedabad         62.0  2023-05-26
# 1023            Narendra Modi Stadium, Ahmedabad          NaN  2023-05-29
#
#                            winner        city outcome  match_number  \
# ...

# %%
df2=pd.read_csv(r"D:\MACHINE LARNING PROJECTS\IPL Win Predictor\dataset\deliveries_updated_mens_ipl.csv")
df2
# Out:
#         matchId  inning  over_ball  over  ball           batting_team  \
# 0        335982       1        0.1     0     1  Kolkata Knight Riders
# 1        335982       1        0.2     0     2  Kolkata Knight Riders
# 2        335982       1        0.3     0     3  Kolkata Knight Riders
# 3        335982       1        0.4     0     4  Kolkata Knight Riders
# 4        335982       1        0.5     0     5  Kolkata Knight Riders
# ...         ...     ...        ...   ...   ...                    ...
# 243812  1370353       2       14.2    14     2    Chennai Super Kings
# 243813  1370353       2       14.3    14     3    Chennai Super Kings
# 243814  1370353       2       14.4    14     4    Chennai Super Kings
# 243815  1370353       2       14.5    14     5    Chennai Super Kings
# 243816  1370353       2       14.6    14     6    Chennai Super Kings
#
#                        bowling_team      batsman  non_striker     bowler  \
# ...

# %%
df2.columns
# Out:
# Index(['matchId', 'inning', 'over_ball', 'over', 'ball', 'batting_team',
#        'bowling_team', 'batsman', 'non_striker', 'bowler', 'batsman_runs',
#        'extras', 'isWide', 'isNoBall', 'Byes', 'LegByes', 'Penalty',
#        'dismissal_kind', 'player_dismissed', 'date'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['venue', 'winner_runs', 'date', 'winner', 'city', 'outcome',
#        'match_number', 'team1', 'eliminator', 'team2', 'winner_wickets',
#        'toss_winner', 'toss_decision', 'tv_umpire', 'season',
#        'player_of_match', 'matchId'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['match_id', 'season', 'start_date', 'venue', 'innings', 'ball',
#        'batting_team', 'bowling_team', 'striker', 'non_striker', 'bowler',
#        'runs_off_bat', 'extras', 'wides', 'noballs', 'byes', 'legbyes',
#        'penalty', 'wicket_type', 'player_dismissed', 'other_wicket_type',
#        'other_player_dismissed'],
#       dtype='object')

# %%
df2['total_runs'] = df2['batsman_runs'] + df2['extras']
df2
# Out:
#         matchId  inning  over_ball  over  ball           batting_team  \
# 0        335982       1        0.1     0     1  Kolkata Knight Riders
# 1        335982       1        0.2     0     2  Kolkata Knight Riders
# 2        335982       1        0.3     0     3  Kolkata Knight Riders
# 3        335982       1        0.4     0     4  Kolkata Knight Riders
# 4        335982       1        0.5     0     5  Kolkata Knight Riders
# ...         ...     ...        ...   ...   ...                    ...
# 243812  1370353       2       14.2    14     2    Chennai Super Kings
# 243813  1370353       2       14.3    14     3    Chennai Super Kings
# 243814  1370353       2       14.4    14     4    Chennai Super Kings
# 243815  1370353       2       14.5    14     5    Chennai Super Kings
# 243816  1370353       2       14.6    14     6    Chennai Super Kings
#
#                        bowling_team      batsman  non_striker     bowler  ...  \
# ...

# %%
total_runs=df2.groupby(['matchId','inning']).sum()['total_runs'].add(1).reset_index()
total_runs=total_runs[total_runs['inning']==1]
total_runs
# Out:
#       matchId  inning  total_runs
# 0      335982       1         223
# 2      335983       1         241
# 4      335984       1         130
# 6      335985       1         166
# 8      335986       1         111
# ...       ...     ...         ...
# 2065  1359544       1         198
# 2067  1370350       1         173
# 2069  1370351       1         183
# 2071  1370352       1         234
# 2073  1370353       1         215
#
# [1024 rows x 3 columns]

# %%
df
# Out:
#         match_id  season  start_date                             venue  \
# 0         335982    2008  2008-04-18             M Chinnaswamy Stadium
# 1         335982    2008  2008-04-18             M Chinnaswamy Stadium
# 2         335982    2008  2008-04-18             M Chinnaswamy Stadium
# 3         335982    2008  2008-04-18             M Chinnaswamy Stadium
# 4         335982    2008  2008-04-18             M Chinnaswamy Stadium
# ...          ...     ...         ...                               ...
# 243810   1370353    2023  2023-05-29  Narendra Modi Stadium, Ahmedabad
# 243811   1370353    2023  2023-05-29  Narendra Modi Stadium, Ahmedabad
# 243812   1370353    2023  2023-05-29  Narendra Modi Stadium, Ahmedabad
# 243813   1370353    2023  2023-05-29  Narendra Modi Stadium, Ahmedabad
# 243814   1370353    2023  2023-05-29  Narendra Modi Stadium, Ahmedabad
#
#         innings  ball           batting_team                 bowling_team  \
# ...

# %%
for col in df2.columns:
    print(f"{col}:{df2[col].nunique()}")
# Out:
# matchId:1024
# inning:6
# over_ball:182
# over:20
# ball:10
# batting_team:18
# bowling_team:18
# batsman:637
# non_striker:626
# bowler:503
# batsman_runs:7
# extras:7
# isWide:5
# isNoBall:4
# Byes:4
# LegByes:5
# Penalty:1
# dismissal_kind:10
# player_dismissed:602
# date:762
# total_runs:8

# %%
df2.drop(columns=['Penalty'],inplace=True)

# %%
df2
# Out:
#         matchId  inning  over_ball  over  ball           batting_team  \
# 0        335982       1        0.1     0     1  Kolkata Knight Riders
# 1        335982       1        0.2     0     2  Kolkata Knight Riders
# 2        335982       1        0.3     0     3  Kolkata Knight Riders
# 3        335982       1        0.4     0     4  Kolkata Knight Riders
# 4        335982       1        0.5     0     5  Kolkata Knight Riders
# ...         ...     ...        ...   ...   ...                    ...
# 243812  1370353       2       14.2    14     2    Chennai Super Kings
# 243813  1370353       2       14.3    14     3    Chennai Super Kings
# 243814  1370353       2       14.4    14     4    Chennai Super Kings
# 243815  1370353       2       14.5    14     5    Chennai Super Kings
# 243816  1370353       2       14.6    14     6    Chennai Super Kings
#
#                        bowling_team      batsman  non_striker     bowler  \
# ...

# %%
total_runs.rename(columns={'match_id': 'matchId', 'innings': 'inning'}, inplace=True)

if 'matchId' not in df1.columns:
    print("Error: 'matchId' column missing in df1")

match_df = df1.merge(total_runs[['matchId', 'inning']], on='matchId', how='left')

match_df
# Out:
#                                            venue  winner_runs        date  \
# 0                          M Chinnaswamy Stadium        140.0  2008-04-18
# 1     Punjab Cricket Association Stadium, Mohali         33.0  2008-04-19
# 2                               Feroz Shah Kotla          NaN  2008-04-19
# 3                               Wankhede Stadium          NaN  2008-04-20
# 4                                   Eden Gardens          NaN  2008-04-20
# ...                                          ...          ...         ...
# 1019            M Chinnaswamy Stadium, Bengaluru          NaN  2023-05-21
# 1020    MA Chidambaram Stadium, Chepauk, Chennai         15.0  2023-05-23
# 1021    MA Chidambaram Stadium, Chepauk, Chennai         81.0  2023-05-24
# 1022            Narendra Modi Stadium, Ahmedabad         62.0  2023-05-26
# 1023            Narendra Modi Stadium, Ahmedabad          NaN  2023-05-29
#
#                            winner        city outcome  match_number  \
# ...

# %%
match_df['team1'].value_counts()
# Out:
# team1
# Royal Challengers Bangalore    135
# Chennai Super Kings            120
# Mumbai Indians                 118
# Kolkata Knight Riders          112
# Rajasthan Royals                96
# Kings XI Punjab                 92
# Delhi Daredevils                85
# Sunrisers Hyderabad             76
# Deccan Chargers                 39
# Delhi Capitals                  34
# Punjab Kings                    27
# Pune Warriors                   23
# Gujarat Lions                   16
# Lucknow Super Giants            15
# Gujarat Titans                  15
# Rising Pune Supergiants          7
# Rising Pune Supergiant           7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
match_df['team1']=match_df['team1'].replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['team1']=match_df['team1'].replace('Delhi Daredevils','Delhi Capitals')
match_df['team1']=match_df['team1'].replace('Kings XI Punjab','Punjab Kings')
match_df['team2']=match_df['team2'].replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['team2']=match_df['team2'].replace('Delhi Daredevils','Delhi Capitals')
match_df['team2']=match_df['team2'].replace('Kings XI Punjab','Punjab Kings')

# %%
teams = ['Kolkata Knight Riders', 
         'Chennai Super Kings',
         'Punjab Kings', 
         'Rajasthan Royals',
         'Mumbai Indians',
         'Delhi Capitals',
         'Royal Challengers Bangalore',
         'Sunrisers Hyderabad']

# %%
match_df=match_df[match_df['team1'].isin(teams)]
match_df=match_df[match_df['team2'].isin(teams)]

# %%
match_df['team2'].value_counts()
# Out:
# team2
# Mumbai Indians                 117
# Sunrisers Hyderabad            114
# Kolkata Knight Riders          112
# Delhi Capitals                 108
# Rajasthan Royals               104
# Punjab Kings                   101
# Chennai Super Kings             98
# Royal Challengers Bangalore     96
# Name: count, dtype: int64

# %%
match_df['team1'].value_counts()
# Out:
# team1
# Royal Challengers Bangalore    121
# Punjab Kings                   110
# Chennai Super Kings            110
# Delhi Capitals                 108
# Mumbai Indians                 105
# Sunrisers Hyderabad            105
# Kolkata Knight Riders          104
# Rajasthan Royals                87
# Name: count, dtype: int64

# %%
print("match_df shape:", match_df.shape)
print("df shape:", df.shape)
print("df1 shape:", df1.shape)
print("df2 shape:", df2.shape)
# Out:
# match_df shape: (850, 18)
# df shape: (243815, 22)
# df1 shape: (1024, 17)
# df2 shape: (243817, 20)

# %%
match_df
# Out:
#                                                   venue  winner_runs  \
# 0                                 M Chinnaswamy Stadium        140.0
# 1            Punjab Cricket Association Stadium, Mohali         33.0
# 2                                      Feroz Shah Kotla          NaN
# 3                                      Wankhede Stadium          NaN
# 4                                          Eden Gardens          NaN
# ...                                                 ...          ...
# 1013  Himachal Pradesh Cricket Association Stadium, ...         15.0
# 1014  Rajiv Gandhi International Stadium, Uppal, Hyd...          NaN
# 1015  Himachal Pradesh Cricket Association Stadium, ...          NaN
# 1016                        Arun Jaitley Stadium, Delhi         77.0
# 1018                           Wankhede Stadium, Mumbai          NaN
#
#             date                       winner        city outcome  \
# 0     2008-04-18        Kolkata Knight Riders   Bangalore     NaN
# ...

# %%
match_df = match_df.merge(total_runs, left_on=['matchId', 'inning'], right_on=['matchId', 'inning'], how='left')

# %%
match_df.columns
# Out:
# Index(['venue', 'winner_runs', 'date', 'winner', 'city', 'outcome',
#        'match_number', 'team1', 'eliminator', 'team2', 'winner_wickets',
#        'toss_winner', 'toss_decision', 'tv_umpire', 'season',
#        'player_of_match', 'matchId', 'inning', 'total_runs'],
#       dtype='object')

# %%
match_df=match_df[['winner','city','matchId','total_runs']]

# %%
match_df
# Out:
#                           winner        city  matchId  total_runs
# 0          Kolkata Knight Riders   Bangalore   335982         223
# 1            Chennai Super Kings  Chandigarh   335983         241
# 2               Delhi Daredevils       Delhi   335984         130
# 3    Royal Challengers Bangalore      Mumbai   335985         166
# 4          Kolkata Knight Riders     Kolkata   335986         111
# ..                           ...         ...      ...         ...
# 845               Delhi Capitals  Dharamsala  1359538         214
# 846  Royal Challengers Bangalore   Hyderabad  1359539         187
# 847             Rajasthan Royals  Dharamsala  1359540         188
# 848          Chennai Super Kings       Delhi  1359541         224
# 849               Mumbai Indians      Mumbai  1359543         201
#
# [850 rows x 4 columns]

# %%
second_innings=match_df.merge(df2,on='matchId')
second_innings
# Out:
#                        winner       city  matchId  total_runs_x  inning  \
# 0       Kolkata Knight Riders  Bangalore   335982           223       1
# 1       Kolkata Knight Riders  Bangalore   335982           223       1
# 2       Kolkata Knight Riders  Bangalore   335982           223       1
# 3       Kolkata Knight Riders  Bangalore   335982           223       1
# 4       Kolkata Knight Riders  Bangalore   335982           223       1
# ...                       ...        ...      ...           ...     ...
# 202513         Mumbai Indians     Mumbai  1359543           201       2
# 202514         Mumbai Indians     Mumbai  1359543           201       2
# 202515         Mumbai Indians     Mumbai  1359543           201       2
# 202516         Mumbai Indians     Mumbai  1359543           201       2
# 202517         Mumbai Indians     Mumbai  1359543           201       2
#
#         over_ball  over  ball           batting_team  \
# ...

# %%
second_innings = second_innings[second_innings['inning']==2]
second_innings.shape
# Out:
# (97646, 23)

# %%
second_innings['batting_team']=second_innings['batting_team'].replace('Deccan Chargers','Sunrisers Hyderabad')
second_innings['batting_team']=second_innings['batting_team'].replace('Delhi Daredevils','Delhi Capitals')
second_innings['batting_team']=second_innings['batting_team'].replace('Kings XI Punjab','Punjab Kings')
second_innings['bowling_team']=second_innings['bowling_team'].replace('Deccan Chargers','Sunrisers Hyderabad')
second_innings['bowling_team']=second_innings['bowling_team'].replace('Delhi Daredevils','Delhi Capitals')
second_innings['bowling_team']=second_innings['bowling_team'].replace('Kings XI Punjab','Punjab Kings')

# %%
second_innings['batting_team'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Punjab Kings', 'Delhi Capitals',
#        'Kolkata Knight Riders', 'Rajasthan Royals', 'Mumbai Indians',
#        'Chennai Super Kings', 'Sunrisers Hyderabad'], dtype=object)

# %%
# Ensure there are no NaN values in 'total_runs_y'
second_innings['total_runs_y'] = second_innings['total_runs_y'].fillna(0)

# Compute cumulative sum of total runs for each match
second_innings['current_Score'] = second_innings.groupby('matchId')['total_runs_y'].cumsum()

# Display results
print(second_innings[['matchId', 'inning', 'over_ball', 'current_Score']].head())
# Out:
#      matchId  inning  over_ball  current_Score
# 124   335982       2        0.1              1
# 125   335982       2        0.2              2
# 126   335982       2        0.3              2
# 127   335982       2        0.4              3
# 128   335982       2        0.5              4

# %%
second_innings['runs_left'] = second_innings['total_runs_x'] - second_innings['current_Score']
second_innings
# Out:
#                        winner       city  matchId  total_runs_x  inning  \
# 124     Kolkata Knight Riders  Bangalore   335982           223       2
# 125     Kolkata Knight Riders  Bangalore   335982           223       2
# 126     Kolkata Knight Riders  Bangalore   335982           223       2
# 127     Kolkata Knight Riders  Bangalore   335982           223       2
# 128     Kolkata Knight Riders  Bangalore   335982           223       2
# ...                       ...        ...      ...           ...     ...
# 202513         Mumbai Indians     Mumbai  1359543           201       2
# 202514         Mumbai Indians     Mumbai  1359543           201       2
# 202515         Mumbai Indians     Mumbai  1359543           201       2
# 202516         Mumbai Indians     Mumbai  1359543           201       2
# 202517         Mumbai Indians     Mumbai  1359543           201       2
#
#         over_ball  over  ball                 batting_team  \
# ...

# %%
second_innings['balls_left'] = 120 - (second_innings['over']*6 +second_innings['ball'])
second_innings
# Out:
#                        winner       city  matchId  total_runs_x  inning  \
# 124     Kolkata Knight Riders  Bangalore   335982           223       2
# 125     Kolkata Knight Riders  Bangalore   335982           223       2
# 126     Kolkata Knight Riders  Bangalore   335982           223       2
# 127     Kolkata Knight Riders  Bangalore   335982           223       2
# 128     Kolkata Knight Riders  Bangalore   335982           223       2
# ...                       ...        ...      ...           ...     ...
# 202513         Mumbai Indians     Mumbai  1359543           201       2
# 202514         Mumbai Indians     Mumbai  1359543           201       2
# 202515         Mumbai Indians     Mumbai  1359543           201       2
# 202516         Mumbai Indians     Mumbai  1359543           201       2
# 202517         Mumbai Indians     Mumbai  1359543           201       2
#
#         over_ball  over  ball                 batting_team  \
# ...

# %%
second_innings['player_dismissed'] = second_innings['player_dismissed'].fillna(0)
second_innings
# Out:
#                        winner       city  matchId  total_runs_x  inning  \
# 124     Kolkata Knight Riders  Bangalore   335982           223       2
# 125     Kolkata Knight Riders  Bangalore   335982           223       2
# 126     Kolkata Knight Riders  Bangalore   335982           223       2
# 127     Kolkata Knight Riders  Bangalore   335982           223       2
# 128     Kolkata Knight Riders  Bangalore   335982           223       2
# ...                       ...        ...      ...           ...     ...
# 202513         Mumbai Indians     Mumbai  1359543           201       2
# 202514         Mumbai Indians     Mumbai  1359543           201       2
# 202515         Mumbai Indians     Mumbai  1359543           201       2
# 202516         Mumbai Indians     Mumbai  1359543           201       2
# 202517         Mumbai Indians     Mumbai  1359543           201       2
#
#         over_ball  over  ball                 batting_team  \
# ...

# %%
second_innings['player_dismissed'] = second_innings['player_dismissed'].apply(lambda x: 0 if x == 0 else 1)
second_innings['player_dismissed'].value_counts()
# Out:
# player_dismissed
# 0    92836
# 1     4810
# Name: count, dtype: int64

# %%
wickets = second_innings.groupby('matchId')['player_dismissed'].cumsum()
second_innings['wickets_remaining'] = 10-wickets
second_innings
# Out:
#                        winner       city  matchId  total_runs_x  inning  \
# 124     Kolkata Knight Riders  Bangalore   335982           223       2
# 125     Kolkata Knight Riders  Bangalore   335982           223       2
# 126     Kolkata Knight Riders  Bangalore   335982           223       2
# 127     Kolkata Knight Riders  Bangalore   335982           223       2
# 128     Kolkata Knight Riders  Bangalore   335982           223       2
# ...                       ...        ...      ...           ...     ...
# 202513         Mumbai Indians     Mumbai  1359543           201       2
# 202514         Mumbai Indians     Mumbai  1359543           201       2
# 202515         Mumbai Indians     Mumbai  1359543           201       2
# 202516         Mumbai Indians     Mumbai  1359543           201       2
# 202517         Mumbai Indians     Mumbai  1359543           201       2
#
#         over_ball  over  ball                 batting_team  \
# ...

# %%
second_innings['crr'] = round((second_innings['current_Score']*6)/(120 - second_innings['balls_left']),2)
second_innings
# Out:
#                        winner       city  matchId  total_runs_x  inning  \
# 124     Kolkata Knight Riders  Bangalore   335982           223       2
# 125     Kolkata Knight Riders  Bangalore   335982           223       2
# 126     Kolkata Knight Riders  Bangalore   335982           223       2
# 127     Kolkata Knight Riders  Bangalore   335982           223       2
# 128     Kolkata Knight Riders  Bangalore   335982           223       2
# ...                       ...        ...      ...           ...     ...
# 202513         Mumbai Indians     Mumbai  1359543           201       2
# 202514         Mumbai Indians     Mumbai  1359543           201       2
# 202515         Mumbai Indians     Mumbai  1359543           201       2
# 202516         Mumbai Indians     Mumbai  1359543           201       2
# 202517         Mumbai Indians     Mumbai  1359543           201       2
#
#         over_ball  over  ball                 batting_team  \
# ...

# %%
second_innings['rrr'] = round((second_innings['runs_left']*6)/(second_innings['balls_left']),2)
second_innings
# Out:
#                        winner       city  matchId  total_runs_x  inning  \
# 124     Kolkata Knight Riders  Bangalore   335982           223       2
# 125     Kolkata Knight Riders  Bangalore   335982           223       2
# 126     Kolkata Knight Riders  Bangalore   335982           223       2
# 127     Kolkata Knight Riders  Bangalore   335982           223       2
# 128     Kolkata Knight Riders  Bangalore   335982           223       2
# ...                       ...        ...      ...           ...     ...
# 202513         Mumbai Indians     Mumbai  1359543           201       2
# 202514         Mumbai Indians     Mumbai  1359543           201       2
# 202515         Mumbai Indians     Mumbai  1359543           201       2
# 202516         Mumbai Indians     Mumbai  1359543           201       2
# 202517         Mumbai Indians     Mumbai  1359543           201       2
#
#         over_ball  over  ball                 batting_team  \
# ...

# %%
def winner(team):
    return 1 if team['batting_team'] == team['winner'] else 0
second_innings['results'] = second_innings.apply(winner,axis=1)
second_innings
# Out:
#                        winner       city  matchId  total_runs_x  inning  \
# 124     Kolkata Knight Riders  Bangalore   335982           223       2
# 125     Kolkata Knight Riders  Bangalore   335982           223       2
# 126     Kolkata Knight Riders  Bangalore   335982           223       2
# 127     Kolkata Knight Riders  Bangalore   335982           223       2
# 128     Kolkata Knight Riders  Bangalore   335982           223       2
# ...                       ...        ...      ...           ...     ...
# 202513         Mumbai Indians     Mumbai  1359543           201       2
# 202514         Mumbai Indians     Mumbai  1359543           201       2
# 202515         Mumbai Indians     Mumbai  1359543           201       2
# 202516         Mumbai Indians     Mumbai  1359543           201       2
# 202517         Mumbai Indians     Mumbai  1359543           201       2
#
#         over_ball  over  ball                 batting_team  \
# ...

# %%
required_data = second_innings[['batting_team','bowling_team','city','runs_left','balls_left','wickets_remaining','total_runs_x','crr','rrr','results']]
required_data
# Out:
#                        batting_team           bowling_team       city  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 125     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 126     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 127     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 128     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# ...                             ...                    ...        ...
# 202513               Mumbai Indians    Sunrisers Hyderabad     Mumbai
# 202514               Mumbai Indians    Sunrisers Hyderabad     Mumbai
# 202515               Mumbai Indians    Sunrisers Hyderabad     Mumbai
# 202516               Mumbai Indians    Sunrisers Hyderabad     Mumbai
# 202517               Mumbai Indians    Sunrisers Hyderabad     Mumbai
#
#         runs_left  balls_left  wickets_remaining  total_runs_x    crr    rrr  \
# ...

# %%
final_data = required_data.sample(required_data.shape[0])

# %%
final_data.dropna(inplace=True)

# %%
final_data = final_data[final_data['balls_left']!=0]

# %%
final_data.to_csv("final_data.csv", index=False)

# %%
from sklearn.model_selection import train_test_split 
x = final_data.iloc[:, :-1]
y = final_data.iloc[:,-1]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=100)
x_train
# Out:
#                        batting_team                 bowling_team         city  \
# 110023               Delhi Capitals  Royal Challengers Bangalore    Bangalore
# 64873                Delhi Capitals                 Punjab Kings   Dharamsala
# 179488             Rajasthan Royals        Kolkata Knight Riders      Sharjah
# 168533          Chennai Super Kings                 Punjab Kings       Mumbai
# 50233                Delhi Capitals                 Punjab Kings   Dharamsala
# ...                             ...                          ...          ...
# 76168         Kolkata Knight Riders               Mumbai Indians       Mumbai
# 65585                Delhi Capitals        Kolkata Knight Riders         Pune
# 18306         Kolkata Knight Riders               Mumbai Indians  East London
# 140386  Royal Challengers Bangalore          Sunrisers Hyderabad    Hyderabad
# 168482          Chennai Super Kings                 Punjab Kings       Mumbai
#
# ...

# %%
x_test
# Out:
#                        batting_team         bowling_team           city  \
# 170656                 Punjab Kings       Mumbai Indians        Chennai
# 192715             Rajasthan Royals         Punjab Kings       Guwahati
# 182443        Kolkata Knight Riders         Punjab Kings         Mumbai
# 106433  Royal Challengers Bangalore         Punjab Kings     Chandigarh
# 84167         Kolkata Knight Riders         Punjab Kings      Abu Dhabi
# ...                             ...                  ...            ...
# 99817         Kolkata Knight Riders  Sunrisers Hyderabad  Visakhapatnam
# 5431                 Delhi Capitals       Mumbai Indians         Mumbai
# 107318        Kolkata Knight Riders     Rajasthan Royals         Mumbai
# 15109         Kolkata Knight Riders     Rajasthan Royals      Cape Town
# 196151          Chennai Super Kings  Sunrisers Hyderabad        Chennai
#
#         runs_left  balls_left  wickets_remaining  total_runs_x    crr    rrr
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse_output=False,drop='first'),['batting_team','bowling_team','city'])
],
remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

pipe = Pipeline([
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred = pipe.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8177557813594954

# %%
pipe.predict_proba(x_test)[0]
# Out:
# array([0.89127076, 0.10872924])

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
final_data['city'].unique()
# Out:
# array(['Mumbai', 'Bangalore', 'Kimberley', 'Cuttack', 'Johannesburg',
#        'Kolkata', 'Hyderabad', 'Delhi', 'Chennai', 'Abu Dhabi', 'Dubai',
#        'Jaipur', 'Chandigarh', 'Durban', 'Pune', 'Ahmedabad',
#        'Dharamsala', 'Indore', 'Bengaluru', 'Raipur', 'Centurion',
#        'Sharjah', 'Ranchi', 'Visakhapatnam', 'Nagpur', 'Navi Mumbai',
#        'Guwahati', 'Cape Town', 'Bloemfontein', 'Port Elizabeth',
#        'East London'], dtype=object)
